# %%
import vrep
import time
import numpy as np
from scipy import linalg
import math
import random

# %% [markdown]
# # Forward Kinematics

# %%
def skew(m):
    return np.array([[0 ,-m[2], m[1]],[m[2], 0, -m[0]], [-m[1], m[0], 0]])

# %%
def revolute(a,q):
    ab = skew(a)
    bottom = -1*np.dot(ab,q)
    return np.array([[a[0]],[a[1]],[a[2]],[bottom[0]],[bottom[1]],[bottom[2]]])

# %%
def brack6(a):
    ws = a[:3]
    vs = a[3:]
    wb = skew(ws)
    ans = np.array([[wb[0,0], wb[0,1], wb[0,2], vs[0]],[wb[1,0], wb[1,1], wb[1,2], vs[1]],[wb[2,0], wb[2,1], wb[2,2], vs[2]], [0,0,0,0]])
    return ans

# %%
def adj(a):
    R = np.array(a[:3,:3])
    p = np.array(a[:3,3])
    ret_top = np.hstack((R, np.zeros((3,3))))
    ret_bottom = np.hstack((skew(p).dot(R), R))
    ret = np.vstack((ret_top,ret_bottom))
    return ret

# %%
# Calculates rotation matrix to euler angles
# The result is the same as MATLAB except the order
# of the euler angles ( x and z are swapped ).
def rotationMatrixToEulerAngles(R) :     
    sy = math.sqrt(R[0,0] * R[0,0] +  R[1,0] * R[1,0])
     
    singular = sy < 1e-6
 
    if  not singular :
        x = math.atan2(R[2,1] , R[2,2])
        y = math.atan2(-R[2,0], sy)
        z = math.atan2(R[1,0], R[0,0])
    else :
        x = math.atan2(-R[1,2], R[1,1])
        y = math.atan2(-R[2,0], sy)
        z = 0
 
    return np.array([x, y, z])

# %%
def eulerAnglesToRotationMatrix(theta) :
     
    R_x = np.array([[1,         0,                  0                   ],
                    [0,         math.cos(theta[0]), -math.sin(theta[0]) ],
                    [0,         math.sin(theta[0]), math.cos(theta[0])  ]
                    ])
         
         
                     
    R_y = np.array([[math.cos(theta[1]),    0,      math.sin(theta[1])  ],
                    [0,                     1,      0                   ],
                    [-math.sin(theta[1]),   0,      math.cos(theta[1])  ]
                    ])
                 
    R_z = np.array([[math.cos(theta[2]),    -math.sin(theta[2]),    0],
                    [math.sin(theta[2]),    math.cos(theta[2]),     0],
                    [0,                     0,                      1]
                    ])
                     
                     
    R = np.dot(R_z, np.dot( R_y, R_x ))
 
    return R

# %%
def euclideanDistance(p1,p2):
    return math.sqrt(math.pow(p1[0]-p2[0],2)+math.pow(p1[1]-p2[1],2)+math.pow(p1[2]-p2[2],2))

# %%
def forward_kinematics(theta):
    
    a0 = np.array([0,0,1])
    q0 = np.array([0,0,0.1045])
    
    a1 = np.array([-1,0,0])
    q1 = np.array([-0.115,0,0.1089])
    
    a2 = np.array([-1,0,0])
    q2 = np.array([-0.115,0,0.3525])
    
    a3 = np.array([-1,0,0]) #Not bad here
    q3 = np.array([-0.115,0,0.5658])
    
    a4 = np.array([0,0,1]) #this joint also doesn't look bad
    q4 = np.array([-0.112,0,0.65])
    
    a5 = np.array([-1,0,0])  #this doesn't look bad, but hard to tell with this joint
    q5 = np.array([-0.11,0,0.6511])
    
    
    M = np.array([[0,0,-1, -0.1940], [0,1,0,0], [1,0,0,0.6511], [0,0,0,1]])
    
    axis = [a0,a1,a2,a3,a4,a5]
    point = [q0,q1,q2,q3,q4,q5]
    
    screw = [revolute(axis[a],point[a]) for a in range(len(axis))]
    
    exp = [linalg.expm(brack6(screw[s])*theta[s]) for s in range (len(screw))]
    
    ex_multiplied = np.identity(4)
    for i in exp:
        ex_multiplied = ex_multiplied.dot(i)
    T = ex_multiplied.dot(M)
    return T

# %%
def inverse_kinematics(T):
    a0 = np.array([0,0,1])
    q0 = np.array([0,0,0.1045])
    
    a1 = np.array([-1,0,0])
    q1 = np.array([-0.115,0,0.1089])
    
    a2 = np.array([-1,0,0])
    q2 = np.array([-0.115,0,0.3525])
    
    a3 = np.array([-1,0,0]) #Not bad here
    q3 = np.array([-0.115,0,0.5658])
    
    a4 = np.array([0,0,1]) #this joint also doesn't look bad
    q4 = np.array([-0.112,0,0.65])
    
    a5 = np.array([-1,0,0])  #this doesn't look bad, but hard to tell with this joint
    q5 = np.array([-0.11,0,0.6511])
    
    
    M = np.array([[0,0,-1, -0.1940], [0,1,0,0], [1,0,0,0.6511], [0,0,0,1]])
    
    axis = [a0,a1,a2,a3,a4,a5]
    point = [q0,q1,q2,q3,q4,q5]
    
    screw = [revolute(axis[a],point[a]) for a in range(len(axis))]
    
    theta = np.repeat(np.pi/8,6).reshape(6,1)
    tolerance = 0.01
    error = 20
    num_iterations = 0
    while (error > tolerance) and (num_iterations < 500):
        exp = [linalg.expm(brack6(screw[s])*theta[s]) for s in range(len(screw))]
        Tc = np.identity(4)
        for i in exp:
            Tc = Tc.dot(i)
        Tc = Tc.dot(M)
        vb = linalg.logm(T.dot(np.linalg.inv(Tc)))
        v = np.array([vb[2,1],vb[0,2],vb[1,0],vb[0,3],vb[1,3],vb[2,3]]).reshape(6,1)
        
        jacobian = []
        jacobian.append(screw[0])
        j = np.identity(4)
        for i in range(len(exp)-1):
            j = j.dot(exp[i])
            jacobian.append(adj(j).dot(screw[i+1]))
            
        space = np.hstack((i for i in jacobian))
        
        thetadot = (np.linalg.inv(np.add(np.transpose(space).dot(space),0.1*np.eye(6)))).dot(np.transpose(space).dot(v))
        theta = np.add(theta,thetadot)
        n = np.linalg.norm(v)
        error = abs(n)
        num_iterations+=1
    print ("Iterations: ",num_iterations)
    if (num_iterations == 500):
        return None
    return theta

# %%
def isColliding(p1,p2,r):
    return euclideanDistance(p1,p2) < 2*r

# %%
def collision_detection(theta, obj, r):
    base = np.array([0,0,0])
    
    a0 = np.array([0,0,1])
    q0 = np.array([0,0,0.1045])
    
    a1 = np.array([-1,0,0])
    q1 = np.array([-0.115,0,0.1089])
    
    a2 = np.array([-1,0,0])
    q2 = np.array([-0.115,0,0.3525])
    
    a3 = np.array([-1,0,0]) #Not bad here
    q3 = np.array([-0.115,0,0.5658])
    
    a4 = np.array([0,0,1]) #this joint also doesn't look bad
    q4 = np.array([-0.112,0,0.65])
    
    a5 = np.array([-1,0,0])  #this doesn't look bad, but hard to tell with this joint
    q5 = np.array([-0.11,0,0.6511])
    
    end = np.array([-0.194,0,0.6511])
    extra = np.array([-0.02,0,0.5658])
    
    M = np.array([[0,0,-1, -0.1940], [0,1,0,0], [1,0,0,0.6511], [0,0,0,1]])
    
    axis = [a0,a1,a2,a3,a4,a5]
    point = [q0,q1,q2,q3,q4,q5]
    
    sphere = [base,q0,q1,q2,q3,q4,end,extra]
    
    screw = [revolute(axis[a],point[a]) for a in range(len(axis))]
    
    exp = [linalg.expm(brack6(screw[s])*theta[s]) for s in range(len(screw))]
    
    #dummies = []
    #for i in range(len(sphere)):
    #    result, dummy = vrep.simxCreateDummy(clientID,.12,(0,255,0),vrep.simx_opmode_blocking)
    #    vrep.simxSetObjectPosition(clientID,dummy,-1,(sphere[i][0],sphere[i][1],sphere[i][2]),vrep.simx_opmode_oneshot)
    #    dummies.append(dummy)    
    
   # time.sleep(1)
    
   # for i in dummies:
   #     vrep.simxRemoveObject(clientID,i,vrep.simx_opmode_blocking)
    
    final_position = [base, q0]
    j = exp[0]
    for i in range(1,len(exp)):
        j = j.dot(exp[i])
        final_position.append(j.dot(np.array([point[i][0],point[i][1],point[i][2],1]).reshape(4,1)))
    for i in range(len(final_position)):
        if isColliding(final_position[i],obj,r):
            return 1
        for j in range(i+1,len(final_position)-1):
            if isColliding(final_position[i],final_position[j],r):
                print (i,j)
                return 1
    return 0

# %%
# Connect to V-REP (raise exception on failure)
clientID = vrep.simxStart('127.0.0.1', 19997, True, True, 5000, 5)
if clientID == -1:
    raise Exception('Failed connecting to remote API server')

# Start simulation
vrep.simxStartSimulation(clientID, vrep.simx_opmode_oneshot)

time.sleep(2)

result, joint_one_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint1', vrep.simx_opmode_blocking)
result, joint_two_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint2', vrep.simx_opmode_blocking)
result, joint_three_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint3', vrep.simx_opmode_blocking)
result, joint_four_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint4', vrep.simx_opmode_blocking)
result, joint_five_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint5', vrep.simx_opmode_blocking)
result, joint_six_handle = vrep.simxGetObjectHandle(clientID, 'UR3_joint6', vrep.simx_opmode_blocking)
result, suction_handle = vrep.simxGetObjectHandle(clientID, 'UR3_connection', vrep.simx_opmode_blocking)


dummies=[0 for i in range(24)]
p=[0 for i in range(24)]
for i in range(24):
    result, dummies[i]=vrep.simxCreateDummy(clientID,.05,(255,255,0),vrep.simx_opmode_blocking)
    vrep.simxSetObjectPosition(clientID,dummies[i],-1,(-0.38,-0.65+i*0.05,0.06),vrep.simx_opmode_oneshot)
    #p(i)=np.array([-0.38,-0.65+i*0.05,0.06])
    
dummies1=[0 for i in range(24)]
p1=[0 for i in range(24)]
for i in range(24):
    result, dummies1[i]=vrep.simxCreateDummy(clientID,.05,(255,255,0),vrep.simx_opmode_blocking)
    vrep.simxSetObjectPosition(clientID,dummies1[i],-1,(-0.38,-0.65+i*0.05,0.43),vrep.simx_opmode_oneshot)
    #p1(i)=(-0.38,-0.65+i*0.05,0.43)
    
dummies2=[0 for i in range (14)]    
p2=[0 for i in range (14)] 
for i in range(14):
    result, dummies2[i]=vrep.simxCreateDummy(clientID,.05,(255,255,0),vrep.simx_opmode_blocking)
    vrep.simxSetObjectPosition(clientID,dummies2[i],-1,(-0.36,-0.65,0.05+i*0.05),vrep.simx_opmode_oneshot)
    #p2(i)=(-0.36,-0.65,0.05+i*0.05)
    
dummies3=[0 for i in range (14)] 
p3=[0 for i in range (14)] 
for i in range(14):
    result, dummies2[i]=vrep.simxCreateDummy(clientID,.05,(255,255,0),vrep.simx_opmode_blocking)
    vrep.simxSetObjectPosition(clientID,dummies2[i],-1,(-0.36,0.52,0.05+i*0.05),vrep.simx_opmode_oneshot)
    #p3(i)=(-0.36,0.52,0.05+i*0.05)
    
#p_obj=[p, p1, p2, p3]
time.sleep(15)
    
# Stop simulation
vrep.simxStopSimulation(clientID, vrep.simx_opmode_oneshot)

# Before closing the connection to V-REP, make sure that the last command sent out had time to arrive. You can guarantee this with (for example):
vrep.simxGetPingTime(clientID)

# Close the connection to V-REP
vrep.simxFinish(clientID)
